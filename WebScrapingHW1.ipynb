# %% [markdown]
# <a href="https://colab.research.google.com/github/LaDiosaNegra/Kristal_SiliconAccra/blob/main/WebScrapingHW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd





# Miami Heat Team Stats
url = "https://www.espn.co.uk/nba/team/stats/_/name/mia/miami-heat"

# Scrape tables from URL
miami_heat_stats = pd.read_html(url)
#print(miami_heat_stats)


# Select the longest table
longest_table = miami_heat_stats[0]

#Display basic info (data types of each column, the number of non-null (non-missing) values, and the memory usage.)
print(longest_table.info())

# Summary Statistics for numeric columns (count, avg, std, min/max values)
print(longest_table.describe())

# Dimensions of row and columns (returns a tuple representing the number of rows and columns)
#print(longest_table.shape)

# total number of elements
#print(longest_table.size)

#  extracts the "FT" column; isolating just the data in the "FT" column for analysis: avg FT % per game
mode_FT = longest_table["FT%"].mode()
print(mode_FT)

# Save the data to a CSV file
miami_heat_stats.to_csv("miami_heat_stats.csv", index=False)

# %%
import pandas as pd

# Revenue Statistics of African Countries
url = "https://statisticstimes.com/economy/african-countries-by-gdp.php"

# Scrape tables from URL
revenue_statistics = pd.read_html(url)



# Longest table #
longest_table = revenue_statistics[2]
print(longest_table)

#Display basic info (data types of each column, the number of non-null (non-missing) values, and the memory usage.)
#print(longest_table.info())

# Summary Statistics for numeric columns (count, avg, std, min/max values)
#print(longest_table.describe())

# Dimensions of row and columns (returns a tuple representing the number of rows and columns)
#print(longest_table.shape)

# total number of elements
#print(longest_table.size)


# first 5
longest_table.head()

# last 5
longest_table.tail()

# Save the DataFrame to a CSV file
longest_table.to_csv("african_countries_gdp.csv", index=False)

# %%
import pandas as pd

# URL of the website
url = "https://en.wikipedia.org/wiki/Greater_Accra_Region"

# Scrape the tables from the website
accra = pd.read_html(url)

# Get the longest table
longest_table = accra[1]

# Print the longest table
print(longest_table)

#Display basic info (data types of each column, the number of non-null (non-missing) values, and the memory usage.)
print(longest_table.info())

# Summary Statistics for numeric columns (count, avg, std, min/max values)
print(longest_table.describe())

# Dimensions of row and columns (returns a tuple representing the number of rows and columns)
print(longest_table.shape)

# total number of elements
print(longest_table.size)

# Correlation: calculate the correlation between numeric columns
#value of 1 means a perfect positive correlation, where as one variable increases,
#      the other also increases.
# value of -1 means a perfect negative correlation,
#      where as one variable increases, the other decreases.
#value of 0 means no linear correlation between the variables.
print(longest_table.corr())
# Out:
#                            District            Capital  \
# 0        Ablekuma Central Municipal    Lartebiokorshie
# 1          Ablekuma North Municipal           Darkuman
# 2           Ablekuma West Municipal           Dansoman
# 3                Accra Metropolitan              Accra
# 4                Accra Metropolitan              Accra
# 5                Accra Metropolitan              Accra
# 6                Accra Metropolitan              Accra
# 7                          Ada East           Ada Foah
# 8                          Ada West               Sege
# 9                  Adenta Municipal             Adenta
# 10               Ashaiman Municipal           Ashaiman
# 11        Ayawaso Central Municipal         Kokomlemle
# 12           Ayawaso East Municipal               Nima
# 13          Ayawaso North Municipal     Accra New Town
# 14           Ayawaso West Municipal           Dzorwulu
# 15             Ga Central Municipal           Sowutuom
# 16                Ga East Municipal            Abokobi
# 17               Ga North Municipal            Amomole
# 18               Ga South Municipal   Ngleshie Amanfro
# 19               Ga South Municipal   Ngleshie Amanfro
# 20                Ga West Municipal           Amasaman
# 21          Korle Klottey Municipal                Osu
# 22        Kpone Katamanso Municipal              Kpone
# 23                 Krowor Municipal             Nungua
# 24        La Dade Kotopon Municipal                 La
# 25  La Nkwantanang Madina Municipal             Madina
# 26              Ledzokuku Municipal             Teshie
# 27                   Ningo Prampram           Prampram
# 28         Okaikwei North Municipal             Tesano
# 29                     Shai Osudoku             Dodowa
# 30                Tema Metropolitan               Tema
# 31                Tema Metropolitan               Tema
# 32              Tema West Municipal  Tema Community 18
# 33            Weija Gbawe Municipal              Weija
#
#                    Constituency          Member of Parliament Party
# 0              Ablekuma Central               Dan Abdul-latif   NDC
# 1                Ablekuma North                Sheila Bartels   NPP
# 2                 Ablekuma West                Ursula G Owusu   NPP
# 3                Ablekuma South       Alfred Okoe Vanderpuije   NDC
# 4                   Odododiodio    Edwin Nii Lante Vanderpuye   NDC
# 5              Okaikwei Central            Patrick Yaw Boamah   NPP
# 6                Okaikwei South                  Dakoa Newman   NPP
# 7                           Ada  Comfort Doyoe Cudjoe-Ghansah   NDC
# 8                          Sege   Christian Corleytey Otuteye   NDC
# 9                        Adenta        Mohammed Adamu Ramadan   NDC
# 10                     Ashaiman                      Ashaiman   NDC
# 11              Ayawaso Central                 Henry Quartey   NPP
# 12                 Ayawaso East            Naser Toure Mahama   NDC
# 13                Ayawaso North           Yussif Issaka Jajah   NDC
# 14                 Ayawaso West                Lydia Alhassan   NPP
# 15               Anyaa-Sowutuom         Dickson Adomako Kissi   NPP
# 16                Dome-Kwabenya              Sarah Adwoa Safo   NPP
# 17                        Trobu                    Moses Anim   NPP
# 18  Bortianor-Ngleshie-Amanfrom              Sylvester Tetteh   NPP
# 19                Domeabra-Obom     Sophia Karen Edem Ackuaku   NDC
# 20                     Amasaman    Akwasi Owusu Afrifa-Mensah   NPP
# 21                Korle Klottey      Zanetor Agyeman-Rawlings   NDC
# 22              Kpone-Katamanso               Joseph Akuerteh   NDC
# 23                       Krowor         Agnes Naa Momo Lartey   NDC
# 24                 Dade Kotopon         Rita Naa Odoley Sowah   NDC
# 25               Abokobi-Madina      Francis-Xavier Kojo Sosu   NDC
# 26                    Ledzokuku         Benjamin Ayiku Nartey   NDC
# 27               Ningo-Prampram          Samuel George Nartey   NDC
# 28               Okaikwei North           Theresa Lardi Awuni   NDC
# 29                 Shai-Osudoku  Linda Obenewaa Akweley Ocloo   NDC
# 30                 Tema Central            Yves Hanson-Nortey   NPP
# 31                    Tema East          Isaac Ashai Odamtten   NDC
# 32                    Tema West      Carlos Kingsley Ahenkora   NPP
# 33                        Weija  Tina Gifty Naa Ayeley Mensah   NPP
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District              34 non-null     object
#  1   Capital               34 non-null     object
#  2   Constituency          34 non-null     object
#  3   Member of Parliament  34 non-null     object
#  4   Party                 34 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB
# None
#                   District Capital      Constituency Member of Parliament  \
# count                   34      34                34                   34
# unique                  29      29                34                   34
# top     Accra Metropolitan   Accra  Ablekuma Central      Dan Abdul-latif
# freq                     4       4                 1                    1
#
#        Party
# count     34
# unique     2
# top      NDC
# freq      20
# (34, 5)
# 170
# Empty DataFrame
# Columns: []
# Index: []
# <ipython-input-74-238efd65e8a9>:33: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(longest_table.corr())

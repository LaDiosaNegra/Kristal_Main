# %% [markdown]
# <a href="https://colab.research.google.com/github/LaDiosaNegra/Kristal_Main/blob/main/PandasNumpy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


z = pd.date_range(start = '1997-10-01', end = '2007-10-01', freq = 'B') #  creates a sequence business days (excluding weekends) from October 1, 1997, to October 1, 2007
z
# Out:
# DatetimeIndex(['1997-10-01', '1997-10-02', '1997-10-03', '1997-10-06',
#                '1997-10-07', '1997-10-08', '1997-10-09', '1997-10-10',
#                '1997-10-13', '1997-10-14',
#                ...
#                '2007-09-18', '2007-09-19', '2007-09-20', '2007-09-21',
#                '2007-09-24', '2007-09-25', '2007-09-26', '2007-09-27',
#                '2007-09-28', '2007-10-01'],
#               dtype='datetime64[ns]', length=2609, freq='B')

# %%
len(z)
# Out:
# 2609

# %%
y = pd.Series(np.random.rand(len(z)), index = z) #creates a pandas Series named y with random values between 0 and 1, these values are assigned to each date in the sequence. The dates in z serve as the index for the series
y
# Out:
# 1997-10-01    0.999621
# 1997-10-02    0.075304
# 1997-10-03    0.951529
# 1997-10-06    0.976098
# 1997-10-07    0.645373
#                 ...
# 2007-09-25    0.900009
# 2007-09-26    0.077716
# 2007-09-27    0.953453
# 2007-09-28    0.883493
# 2007-10-01    0.182277
# Freq: B, Length: 2609, dtype: float64

# %%
z = pd.DataFrame(y)
z
# Out:
#                    0
# 1997-10-01  0.999621
# 1997-10-02  0.075304
# 1997-10-03  0.951529
# 1997-10-06  0.976098
# 1997-10-07  0.645373
# ...              ...
# 2007-09-25  0.900009
# 2007-09-26  0.077716
# 2007-09-27  0.953453
# 2007-09-28  0.883493
# 2007-10-01  0.182277
#
# [2609 rows x 1 columns]

# %%
z[z.index.dayofweek == 4] # filters the date range to only include the dates where the day of the week is 4, which corresponds to Fridays
# Out:
#                    0
# 1997-10-03  0.951529
# 1997-10-10  0.423462
# 1997-10-17  0.379955
# 1997-10-24  0.796961
# 1997-10-31  0.466890
# ...              ...
# 2007-08-31  0.134062
# 2007-09-07  0.610378
# 2007-09-14  0.943922
# 2007-09-21  0.294857
# 2007-09-28  0.883493
#
# [522 rows x 1 columns]

# %%
z[z.index.dayofweek == 4].sum()
# Out:
# 0    268.997128
# dtype: float64

# %%
z.resample('M').mean() #resamples a time series indexed by the date range to a monthly frequency and calculates the mean for each month
# Out:
#                    0
# 1997-10-31  0.597333
# 1997-11-30  0.514575
# 1997-12-31  0.414263
# 1998-01-31  0.545883
# 1998-02-28  0.635671
# ...              ...
# 2007-06-30  0.508343
# 2007-07-31  0.435832
# 2007-08-31  0.446846
# 2007-09-30  0.514911
# 2007-10-31  0.182277
#
# [121 rows x 1 columns]

# %%
z.resample('Y').min()
# Out:
#                    0
# 1997-12-31  0.002128
# 1998-12-31  0.003465
# 1999-12-31  0.015826
# 2000-12-31  0.010027
# 2001-12-31  0.005444
# 2002-12-31  0.004909
# 2003-12-31  0.000365
# 2004-12-31  0.000513
# 2005-12-31  0.000450
# 2006-12-31  0.009868
# 2007-12-31  0.002021

# %%
z.resample('W').max()
# Out:
#                    0
# 1997-10-05  0.999621
# 1997-10-12  0.976098
# 1997-10-19  0.724108
# 1997-10-26  0.869035
# 1997-11-02  0.830494
# ...              ...
# 2007-09-09  0.610378
# 2007-09-16  0.995574
# 2007-09-23  0.566643
# 2007-09-30  0.953453
# 2007-10-07  0.182277
#
# [523 rows x 1 columns]

# %%
z.resample('W').sum()
# Out:
#                    0
# 1997-10-05  2.026454
# 1997-10-12  3.066109
# 1997-10-19  2.622219
# 1997-10-26  3.993167
# 1997-11-02  2.030708
# ...              ...
# 2007-09-09  1.897392
# 2007-09-16  3.398005
# 2007-09-23  1.521934
# 2007-09-30  3.480888
# 2007-10-07  0.182277
#
# [523 rows x 1 columns]

# %%
pd.Grouper(freq = '3M')
# Out:
# TimeGrouper(freq=<3 * MonthEnds>, axis=0, sort=True, dropna=True, closed='right', label='right', how='mean', convention='e', origin='start_day')

# %%
z.groupby(pd.Grouper(freq = '3M')).idxmax() #groups the date range into three-month intervals and finds the index of the maximum value within each group
# Out:
#                     0
# 1997-10-31 1997-10-01
# 1998-01-31 1997-11-18
# 1998-04-30 1998-04-03
# 1998-07-31 1998-07-31
# 1998-10-31 1998-09-15
# 1999-01-31 1998-12-23
# 1999-04-30 1999-02-15
# 1999-07-31 1999-07-05
# 1999-10-31 1999-10-01
# 2000-01-31 1999-11-03
# 2000-04-30 2000-04-18
# 2000-07-31 2000-07-28
# 2000-10-31 2000-10-03
# 2001-01-31 2000-12-08
# 2001-04-30 2001-04-23
# 2001-07-31 2001-05-03
# 2001-10-31 2001-08-14
# 2002-01-31 2002-01-30
# 2002-04-30 2002-04-23
# 2002-07-31 2002-05-27
# 2002-10-31 2002-10-21
# 2003-01-31 2002-12-02
# 2003-04-30 2003-04-21
# 2003-07-31 2003-05-12
# 2003-10-31 2003-09-04
# 2004-01-31 2003-12-24
# 2004-04-30 2004-02-05
# 2004-07-31 2004-07-08
# 2004-10-31 2004-08-20
# 2005-01-31 2004-11-19
# 2005-04-30 2005-03-23
# 2005-07-31 2005-07-25
# 2005-10-31 2005-10-06
# 2006-01-31 2005-11-21
# 2006-04-30 2006-04-03
# 2006-07-31 2006-05-16
# 2006-10-31 2006-10-09
# 2007-01-31 2007-01-11
# 2007-04-30 2007-04-20
# 2007-07-31 2007-06-27
# ...

# %%
pd.date_range('2023-01-01', '2024-01-01',freq = 'WOM-1SUN')
# Out:
# DatetimeIndex(['2023-01-01', '2023-02-05', '2023-03-05', '2023-04-02',
#                '2023-05-07', '2023-06-04', '2023-07-02', '2023-08-06',
#                '2023-09-03', '2023-10-01', '2023-11-05', '2023-12-03'],
#               dtype='datetime64[ns]', freq='WOM-1SUN')
